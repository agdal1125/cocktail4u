# %% [markdown]
# # Cocktail Data Analysis

# %% [markdown]
# ## 1. Getting Data From https://liquor.com

# %% [markdown]
# ### Retrieving  Recipe Links:

# %%
from selenium import webdriver
from selenium.webdriver.support.select import Select
import time

# url to scrape data
base_url = "https://www.liquor.com/recipes/page/"

# selenium driver
driver = webdriver.Chrome("/Users/nowgeun/Desktop/chromedriver")

recipe_links_2 = []

page_nums = range(1,48)
for i in page_nums:

    url = base_url+str(i) 
    driver.get(url)
    
    # Extract block tiles with cocktail information
    tiles = driver.find_elements_by_class_name("card-type-recipe")

    # Extract links to cocktail recipe
    for tile in tiles:

        # link to cocktail recipe
        cocktail_link = tile.find_element_by_class_name("archive-item-headline").find_element_by_tag_name("a").get_attribute("href")
        recipe_links_2.append(cocktail_link)

# %%
print("There are {} recipes".format(len(recipe_links_2)))
print("top 5 links ", recipe_links_2[0:5])
# Out:
# There are 2303 recipes
# top 5 links  ['https://www.liquor.com/recipes/gin-sonic/', 'https://www.liquor.com/recipes/haileys-comet/', 'https://www.liquor.com/recipes/tennessee-summertide/', 'https://www.liquor.com/recipes/sugar-baby/', 'https://www.liquor.com/recipes/miamians-julep/']

# %%
# Save the link information
with open("liquor_com_recipes.csv","w") as d:
    for line in recipe_links_2:
        d.write(line+"\n")
d.close()

# %% [markdown]
# ### Extracting information from respective links

# %%
f = open("liquor_com_recipes.csv","r")
urls_2 = [l.strip() for l in f.readlines()]

# This particular link seems broken. Exclude from analysis
urls_2.remove("https://www.liquor.com/recipes/godfather-101/")

# %%
from bs4 import BeautifulSoup
import requests

cocktail_data = {}

for l in urls_2:
    req = requests.get(l)
    html = req.text
    soup = BeautifulSoup(html,"html.parser")
    
    # Cocktail Name
    name = soup.find("h1",{"itemprop":"name"}).text
    
    
    """
    Not all links include information on spirits, flavors, types.
    Try and Except will be used to avoid errors.
    
    """
    
    # Base Spirit
    
    spirits = []
    try:       
        base_spirits = soup.find("div",{"class":"x-recipe-spirit"}).find_all("a")
        for base in base_spirits:
            spirits.append(base.text)
    except:
        spirits.append("No Data")
    
    # Flavors
    
    flavors = []
    
    try:
        tastes = soup.find("div",{"class":"x-recipe-flavor"}).find_all("a")
        for taste in tastes:
            flavors.append(taste.text)
    except:
        flavors.append("No Data")
        
    # Type
    try:
        cocktail_type = soup.find("div",{"class":"x-recipe-type"}).find("a").text
    except:
        cocktail_type = "No Data"
    # Strength
    try:
        strength = soup.find("div",{"class":"x-recipe-strength"}).find("a").text
    except:
        strength = "No Data"
    
    # Ingredients
    recipe = []
    ingredients = soup.find_all("div",{"class":"x-recipe-unit"})[1:]

    for ing in ingredients:
        try:
            quant = ing.find("div",{"class":"text-right"}).text.strip()
            res_ing = ing.find("div",{"class":"x-recipe-ingredient"}).text.strip()
            
            if (quant and res_ing):
                recipe.append(quant.strip()+"@"+res_ing)
            else:
                pass
        except:
            pass
    
    
    cocktail_data[name] = {"base": spirits,
                           "flavor": flavors,
                           "type": cocktail_type,
                           "strength": strength,
                           "recipe": recipe
                           }

# %%
cocktail_data.keys()
# Out:
ee Rye Sazerac', 'Earl Grey MarTEAni', 'Trash Tiki Citrus Stock', 'Peeping Tom', 'Irish Affogato', 'Manhattan', 'Brother Hal', 'Bonpland', 'Chrysanthemum', 'Absolut Sex on the Beach', 'Lime Mule', 'Bay Breeze', 'Hanna Wallbanger', 'Absolut Lime Soda', 'Absolut Mudslide', 'Absolut French Martini', 'Absolut Citron Gimlet', 'Absolut Vodka Gimlet', 'Espresso Old Fashioned', 'Grapefruit Drop', 'The Swedish Paloma', 'Herb Ginger Julep', 'Absolut White Cosmopolitan', 'Absolut Vodka Martini', 'Half Moon Bay', 'Blackberry Punch', 'Absolut Peppar Bloody Mary', 'Absolut Mimosa', 'Grapefruit Mule', 'Shamrock Shot', 'Local Old Fashioned', 'Rumplesnuggler', "Porter's Old Fashioned", 'Flinn’s Après Steazy', 'Cache Stash', 'Yard Sale', 'Toblerone', 'Apple Chai G&T', 'Curiosity Killed the Cat, You Know', 'French Harvest', 'Golden Purl', 'Coffee & Cigarettes', 'Forest Sprite', 'Painkiller', 'Bitter Hearts Know Better', 'Pisco Sour', 'Cobbler', 'Pisco Bramble', "She's No Gentleman", 'Hot Blooded', 'Suffering Bastard', 'CBD Spritz', 'Picon Punch', 'Celery Sour', 'Lounge Chair Afternoon', 'Improved Dunlop', 'New York Sour', 'Annie Oakley', 'Hello, Sun', 'Golden Geisha', 'Not Tested on Animals', 'Get Off My Isle', 'Strawberry Runner', 'Fixer Upper', 'Topsy Turvy', 'Reverse Manhattan', 'Full Monte', 'Diamond District', 'Downhill Daring', 'Kimchi Gibson', 'Lion’s Tail ...

# %%
import pandas as pd
df = pd.DataFrame(cocktail_data)

# %%
df.head(5)
# Out:
#                                                   Gin Sonic  \
# base                                                  [Gin]
# flavor                                             [Bubbly]
# type                                        Modern Classics
# strength                                             Medium
# recipe    [1 1⁄2 oz@Roku gin, 2 1⁄4 oz@Club soda, 2 1⁄4 ...
#
#                                              Hailey’s Comet  \
# base                  [Bourbon / American Whiskey, Whiskey]
# flavor                                              [Sweet]
# type                                       Frozen / Blended
# strength                                             Medium
# recipe    [1 oz@Peach-infused bourbon*, 3⁄4 oz@Pimm’s bl...
#
#                                        Tennessee Summertide  \
# base                  [Bourbon / American Whiskey, Whiskey]
# flavor                                     [Spirit-forward]
# type                                       Frozen / Blended
# strength                                             Medium
# recipe    [1 1⁄2 oz@Chattanooga 1816 Cask unfiltered bar...
#
#                                                  Sugar Baby  \
# base                  [Bourbon / American Whiskey, Whiskey]
# flavor                                         [Herbaceous]
# type                                       Frozen / Blended
# strength                                             Medium
# recipe    [1@Large seedless watermelon, 1 cup@Bourbon, 1...
#
#                                             Miamian’s Julep  \
# base                  [Bourbon / American Whiskey, Whiskey]
# flavor                                 [Creamy, Herbaceous]
# type                                       Frozen / Blended
# strength                                             Medium
# recipe    [2 oz@Woodinville bourbon, 1 oz@Coconut cream,...
#
#                                                 Cabana Club  \
# base                                               [Sherry]
# flavor                                              [Sweet]
# type                                        Tiki / Tropical
# strength                                             Medium
# recipe    [1 1⁄2 oz@Amontillado sherry, 1 oz@Fresh cocon...
#
#                                                  Holy Water  \
# base                                                  [Rum]
# flavor                       [Fruity/Citrus-forward, Spicy]
# type                                        Tiki / Tropical
# strength                                             Medium
# recipe    [3⁄4 oz@Infused Hamilton Jamaican gold rum or ...
#
#                                             Banana Daiquiri  \
# base                                                  [Rum]
# flavor                       [Fruity/Citrus-forward, Sweet]
# type                                        Tiki / Tropical
# strength                                             Medium
# recipe    [2 oz@Aged rum, 1⁄2 oz@Tempus Fugit crème de b...
#
#                                             Amanyara Mojito  \
# base                                                  [Rum]
# flavor                                  [Herbaceous, Sweet]
# type                                               Classics
# strength                                             Medium
# recipe    [2 oz@Bacardí Superior light rum, 1 oz@Fresh l...
#
#                                                 Honeysuckle  ...  \
# base                                                  [Rum]  ...
# flavor                       [Fruity/Citrus-forward, Sweet]  ...
# type                                        Modern Classics  ...
# strength                                             Medium  ...
# recipe    [2 oz@Angostura seven-year-old rum, 3⁄4 oz@Fre...  ...
#
#                                     Moon Mountain Greyhound  \
# base                                                [Vodka]
# flavor                       [Fruity/Citrus-forward, Sweet]
# type                                        Modern Classics
# strength                                             Medium
# recipe    [1 1⁄4 oz@Moon Mountain Wild Raspberry Flavore...
#
#                                          Citrus Flower Sour  \
# base                                                [Vodka]
# flavor                 [Fruity/Citrus-forward, Sour, Sweet]
# type                                        Modern Classics
# strength                                             Medium
# recipe    [1 1⁄4 oz@Moon Mountain Coastal Citrus Flavore...
#
#                                          The Irish Car Bomb  \
# base                        [Beer, Irish Whiskey, Liqueurs]
# flavor                             [Bubbly, Spirit-forward]
# type                                               Classics
# strength                                             Medium
# recipe    [1⁄2 oz@Baileys Irish cream, 1⁄2 oz@Irish whis...
#
#                 Flaming Dr. Pepper Shot  \
# base              [Beer, Liqueurs, Rum]
# flavor         [Bubbly, Spirit-forward]
# type                              Shots
# strength                         Medium
# recipe    [3⁄4 oz@Amaretto, 1⁄4 oz@Rum]
#
#                                       "Plumdog" Millionaire  \
# base                                                  [Gin]
# flavor                       [Salty/Savory, Spirit-forward]
# type                                        Modern Classics
# strength                                             Strong
# recipe    [2 oz@Bulldog GIn, 1 oz@Japanese plum wine, 1 ...
#
#                                         New Year’s Sparkler  \
# base                                                [Vodka]
# flavor                       [Fruity/Citrus-forward, Sweet]
# type                                        Modern Classics
# strength                                             Medium
# recipe    [1 oz@Berry-flavored vodka, 1 1⁄2 oz@Pomegrana...
#
#                              Finlandia Vodka Wild Berritini  \
# base                                                [Vodka]
# flavor                       [Fruity/Citrus-forward, Sweet]
# type                                        Modern Classics
# strength                                             Medium
# recipe    [3⁄4 oz@Finlandia Wild Berries Fusion Vodka, 1...
#
#                                       VeeV Holiday Highball  \
# base                                             [Liqueurs]
# flavor                              [Fruity/Citrus-forward]
# type                                        Modern Classics
# strength                                             Medium
# recipe    [2 oz@VeeV Açaí Spirit, 1⁄4 oz@Green Chartreus...
#
#                                             Tropical Sunset  \
# base                                                [Vodka]
# flavor                              [Fruity/Citrus-forward]
# type                                        Tiki / Tropical
# strength                                             Medium
# recipe    [1 1⁄2 oz@Van Gogh Pineapple Vodka, 1 oz@Van G...
#
#                                                     Hydrate
# base                                                [Vodka]
# flavor                              [Fruity/Citrus-forward]
# type                                        Modern Classics
# strength                                             Medium
# recipe    [2 oz@Organic cucumber vodka, 2 1⁄2 oz@Puréed ...
#
# [5 rows x 2219 columns]

# %%
df.to_csv("Cocktail_Data.csv")
